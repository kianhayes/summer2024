# %%
import os
import yt

os.chdir('/home/haye6406@benedictine.edu/summer2024/athena/blast/data')

ds = yt.load('Blast.out1.*.athdf')
directions = ['x', 'y', 'z']
variable = ('gas', 'temperature')
i=0
for ds in ds:
    s = yt.SlicePlot(ds, 'z', variable)
    s.set_cmap(variable, 'inferno')
    s.annotate_title(variable)
    s.save(f'~/summer2024/athena/blast/plots/{i}.png')
    i += 1
# Out:
# yt : [WARNING  ] 2024-05-29 15:04:57,802 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2024-05-29 15:04:57,803 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2024-05-29 15:04:57,803 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2024-05-29 15:04:57,804 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2024-05-29 15:04:57,842 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-05-29 15:04:57,843 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2024-05-29 15:04:57,844 Parameters: domain_left_edge          = [-1. -1. -1.]
# yt : [INFO     ] 2024-05-29 15:04:57,844 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2024-05-29 15:04:57,845 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-05-29 15:04:58,490 xlim = -1.000000 1.000000
# yt : [INFO     ] 2024-05-29 15:04:58,491 ylim = -1.000000 1.000000
# yt : [INFO     ] 2024-05-29 15:04:58,493 xlim = -1.000000 1.000000
# yt : [INFO     ] 2024-05-29 15:04:58,494 ylim = -1.000000 1.000000
# ...
